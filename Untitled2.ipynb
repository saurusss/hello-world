# %%
import pandas as pd
import numpy as np
loc = pd.read_excel(r'C:\Users\sauru\Documents\GitHub\hello-world\location\loc_180818.xlsx')
print(loc)
aa =loc.set_index('mgmtNum')

print(aa.index)

loc.columns

print(aa.columns,'\n',
      aa.index,'\n',
      loc.index
)

# %%
loc[0:1]
# Out:
#                      mgmtNum bldgName            addr   Latitude   Longitude
# 0  1111012300101540001017647   광화문우체국  서울특별시 종로구 종로 6  37.569801  126.978084

# %%
aa[0:1]
# Out:
#                           bldgName            addr   Latitude   Longitude
# mgmtNum
# 1111012300101540001017647   광화문우체국  서울특별시 종로구 종로 6  37.569801  126.978084

# %%
for i in aa.index:
    print(i)
#     for j in aa.index:
#         print(j)
#     temp_mgmtNum = aa[aa.index == i].mgmtNum
#     print(temp_mgmtNum)
#     temp_lat = aa[aa.latitude]
#     print(temp_mgmtNum, temp_lat)
#     for j in aa.index:
#        pass
# Out:
# 1111012300101540001017647
# 1111013800100390002016386
# 1111014100101550000025934
# 1111015900101510006016569
# 1111016300100980006013057
# 1111016900101110003008193
# 1111017500100530025002881
# 1111018600101330001024551
# 1114011300100700001022594
# 1114012000101230000020807
# 1114012400100210001000001
# 1114014400101730003016382
# 1114015000103120001000001
# 1114016200103690036007027
# 1114016300101130001009833
# 1117010100100220000026185
# 1117010500100120001023801
# 1117011200100270004000001
# 1117011700100010157018156
# 1117012500101420000013835
# 1117012900103010104011331
# 1117013000105250000008733
# 1117013100106570044005376
# 1117013600102170028002512
# 1120010300103560000022686
# 1120010500105230003020281
# 1120010700102840000018828
# 1120011000102230000014445
# 1120011400100330029010092
# 1120012200102280005001539
# 1121510100100430005000487
# 1121510300105870000009878
# 1121510500106360007013270
# 1121510700100180010016915
# 1123010100101170023030021
# ...

# %%
print(loc.columns, 
loc.index)
# Out:
# Index(['mgmtNum', 'bldgName', 'addr', 'Latitude', 'Longitude'], dtype='object') RangeIndex(start=0, stop=1000, step=1)

# %%
for i in loc:
    print(i)
# Out:
# mgmtNum
# bldgName
# Latitude
# Longitude

# %%
print(range(loc))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-5e366350ccfe> in <module>()
# ----> 1 print(range(loc))
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer

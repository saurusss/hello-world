# %%
import pandas as pd
import numpy as np
import sqlite3
import math
 

print("*"*10, "start of job", "*"*10)
conn = sqlite3.connect(r'C:\Temp\loc_post.db')
df = pd.read_sql_query("select * from position where nearestBranch is null", conn)
cnt = len(df)
# Out:
# ********** start of job **********

# %%
conn = sqlite3.connect(r'C:\Temp\loc_post.db')
cursor = conn.cursor()

# %%
df = pd.read_sql_query("select * from position where nearestBranch is null", conn)
cnt = len(df)
cnt -= 1

# %%
conn.close()

# %%
del df['index']
df = df.set_index('officeName')
# df = df.sort_index(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4a3d276cdc02> in <module>()
# ----> 1 del df['index']
# ...

# %%
df
# Out:
#             level_0                             address   latitude  \
# officeName
# 가남우체국             0                   경기 여주시 가남읍 태평로 29  37.201739
# 가정행정법원출장소         1            서울특별시 서초구 강남대로 193 (양재동)  37.473862
# 가평북면우체국           2           경기 가평군 북면 가화로 967 (북면우체국)  37.882173
# 가평우체국             3            경기 가평군 가평읍 보납로 2 (가평우체국)  37.831068
# 가평조종우체국           4         경기 가평군 조종면 현창로 31 (가평조종우체국)  37.817511
# 강상우체국             5                 경기 양평군 강상면 양평대교길 87  37.482517
# 강천우체국             6                경기 여주시 강천면 간매1길 10-1  37.271142
# 강하우체국             7                   경기 양평군 강하면 운심길 41  37.496188
# 강화갑곳리(취)          8              인천광역시 강화군 강화읍 갑룡길 33-1  37.743730
# 강화우체국             9              인천광역시 강화군 강화읍 강화대로 384  37.746005
# 개군우체국            10                  경기 양평군 개군면 하자포길 33  37.425862
# 검단우체국            11              인천광역시 서구 검단로 487 (마전동)  37.594911
# 경기광주우체국          12             경기 광주시 행정타운로 49-10(송정동)  37.427831
# ...

# %%
df
# df = df.values(by='address',ascending=False)
# del df['level_0']
# Out:
#                                        address   latitude   longitude  \
# officeName
# 가남우체국                        경기 여주시 가남읍 태평로 29  37.201739  127.545135
# 가정행정법원출장소             서울특별시 서초구 강남대로 193 (양재동)  37.473862  127.030459
# 가평북면우체국              경기 가평군 북면 가화로 967 (북면우체국)  37.882173  127.547377
# 가평우체국                 경기 가평군 가평읍 보납로 2 (가평우체국)  37.831068  127.510743
# 가평조종우체국            경기 가평군 조종면 현창로 31 (가평조종우체국)  37.817511  127.348426
# 강상우체국                      경기 양평군 강상면 양평대교길 87  37.482517  127.485183
# 강천우체국                     경기 여주시 강천면 간매1길 10-1  37.271142  127.715848
# 강하우체국                        경기 양평군 강하면 운심길 41  37.496188  127.410790
# 강화갑곳리(취)                인천광역시 강화군 강화읍 갑룡길 33-1  37.743730  126.496037
# 강화우체국                   인천광역시 강화군 강화읍 강화대로 384  37.746005  126.487727
# 개군우체국                       경기 양평군 개군면 하자포길 33  37.425862  127.536748
# 검단우체국                   인천광역시 서구 검단로 487 (마전동)  37.594911  126.677775
# ...

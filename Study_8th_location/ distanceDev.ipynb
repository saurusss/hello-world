# %%
import sqlite3
import pandas as pd
import numpy as numpy
loc = pd.read_excel(r'C:\Users\Administrator\Documents\Github\hello-world\Study_8th_location\loc_180824.xlsx')
print(loc)
# Out:
#              관내국                                  주소   Latitude   Longitude
# 0          가남우체국                   경기 여주시 가남읍 태평로 29  37.201739  127.545135
# 1      가정행정법원출장소            서울특별시 서초구 강남대로 193 (양재동)  37.473862  127.030459
# 2        가평북면우체국           경기 가평군 북면 가화로 967 (북면우체국)  37.882173  127.547377
# 3          가평우체국            경기 가평군 가평읍 보납로 2 (가평우체국)  37.831068  127.510743
# 4        가평조종우체국         경기 가평군 조종면 현창로 31 (가평조종우체국)  37.817511  127.348426
# 5          강상우체국                 경기 양평군 강상면 양평대교길 87  37.482517  127.485183
# 6          강천우체국                경기 여주시 강천면 간매1길 10-1  37.271142  127.715848
# 7          강하우체국                   경기 양평군 강하면 운심길 41  37.496188  127.410790
# 8       강화갑곳리(취)              인천광역시 강화군 강화읍 갑룡길 33-1  37.743730  126.496037
# 9          강화우체국              인천광역시 강화군 강화읍 강화대로 384  37.746005  126.487727
# 10         개군우체국                  경기 양평군 개군면 하자포길 33  37.425862  127.536748
# ...

# %%
import pandas as pd
import numpy as numpy
import sqlite3
 
conn = sqlite3.connect(r'C:\Users\Administrator\Documents\Github\hello-world\Study_8th_location\loc_post.db')
cursor = conn.cursor()

PDB = cursor.execute("SELECT * FROM position where nearest" )
# for i in loc:
#     cursor.execute("INSERT INTO position VALUES (loc.mgmtNum[i], loc.buildName[i], loc.addr[i], loc.latitude[i], loc.longitude[i])")

# %%
rows = cursor.fetchall()
for row in rows:
        print(row)
# Out:
# (0, '가남우체국', '경기 여주시 가남읍 태평로 29', 37.2017393, 127.5451354, None)
# (1, '가정행정법원출장소', '서울특별시 서초구 강남대로 193 (양재동)', 37.4738618, 127.0304589, None)
# (2, '가평북면우체국', '경기 가평군 북면 가화로 967 (북면우체국)', 37.8821732, 127.5473771, None)
# (3, '가평우체국', '경기 가평군 가평읍 보납로 2 (가평우체국)', 37.8310677, 127.5107432, None)
# (4, '가평조종우체국', '경기 가평군 조종면 현창로 31 (가평조종우체국)', 37.8175108, 127.3484262, None)
# (5, '강상우체국', '경기 양평군 강상면 양평대교길 87', 37.4825165, 127.4851829, None)
# (6, '강천우체국', '경기 여주시 강천면 간매1길 10-1', 37.2711424, 127.7158482, None)
# (7, '강하우체국', '경기 양평군 강하면 운심길 41', 37.4961878, 127.4107898, None)
# (8, '강화갑곳리(취)', '인천광역시 강화군 강화읍 갑룡길 33-1', 37.7437302, 126.4960365, None)
# (9, '강화우체국', '인천광역시 강화군 강화읍 강화대로 384', 37.7460051, 126.4877269, None)
# (10, '개군우체국', '경기 양평군 개군면 하자포길 33', 37.4258617, 127.5367478, None)
# (11, '검단우체국', '인천광역시 서구 검단로 487 (마전동)', 37.5949114, 126.6777746, None)
# (12, '경기광주우체국', '경기 광주시 행정타운로 49-10(송정동)', 37.4278308, 127.2531667, None)
# ...

# %%
cursor = con.cursor()

# %%
conn.close()

# %%
import pandas as pd
import numpy as numpy
 
con = sqlite3.connect(r'C:\Users\Administrator\Documents\Github\hello-world\Study_8th_location\loc_post.db')
cursor = con.cursor()

# %%
PDB = cursor.execute("SELECT * FROM position " )

# %%
dir(PDB)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'arraysize',
#  'close',
#  'connection',
#  'description',
#  'execute',
#  'executemany',
#  'executescript',
#  'fetchall',
#  'fetchmany',
#  'fetchone',
#  'lastrowid',
#  'row_factory',
#  'rowcount',
#  'setinputsizes',
#  'setoutputsize']

# %%
type(PDB)
# Out:
# sqlite3.Cursor

# %%
i = 1
print(i)
print(pdb[i][2]) 
print ('distance'      )
print(abs(float(pdb[i][4])- float(y))**2)
print(abs(float(pdb[i][5])- float(x))**2)
#                    - float(y) 
# #        + (flot(pdb[i][5]) - flot(x)
# Out:
# 1
# 종로1-4가동주민센터, 종로2가우체국
# distance
# 7.637012099910443e-07
# 0.010874700000002235

# %%
# for i in pdb[1:]:
#     wordkf.append('bldgName' :pdb[i][2], 
#                   'distance' : sqrt(abs(float(pdb[i][4])- float(y))**2 +abs(float(pdb[i][5])- float(x))**2**2)
               
#     print(workdf)
workdf.append {"aaa":"bbb", "ccc":"ddd"}
# Out:
#   File "<ipython-input-69-b945735faa75>", line 6
#     workdf.append {"aaa":"bbb", "ccc":"ddd"}
#                   ^
# SyntaxError: invalid syntax

# %%
 
con.commit()
con.close()

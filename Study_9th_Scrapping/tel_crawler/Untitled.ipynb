# %%
import pandas as pd
pn = pd.read_csv(r'c:\\TEMP\\postAddr.csv')
wurls = []
for i in pn:
    wurls = wurls.append("https://www.114.co.kr/search/list.do?menuKey=116&searchWord=" + pn[i] + "#none")
    
start_urls = wurls

# %%
list(start_urls[0])
# Out:
# ['https://www.114.co.kr/search/list.do?menuKey=116&searchWord=100군사우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가곡우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가남우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가덕우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가야곡우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가정행정법원출장소#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가평북면우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가평우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=가평조종우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=간성우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=갈산우체국#none',
#  'https://www.114.co.kr/search/list.do?menuKey=116&searchWord=감물우체국#none',
# ...

# %%
type(start_urls)
# Out:
# list
